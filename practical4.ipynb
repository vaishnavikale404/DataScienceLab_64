# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavikale404/DataScienceLab_64/blob/main/practical4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MEAN, MEDIAN, MODE

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Take numbers from user
data = list(map(float, input("Enter numbers separated by space: ").split()))

# Convert list to numpy array
data = np.array(data)

# Calculate mean, median and mode
mean = np.mean(data)
median = np.median(data)
mode = stats.mode(data)[0]

# Print results
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
# Out:
# Enter numbers separated by space: 2
# Mean: 2.0
# Median: 2.0
# Mode: 2.0

# %% [markdown]
# VARIENCE

# %%
# Compute variance
variance_value = np.var(data_np)
print(f"Variance: {variance_value:.2f}")
# Out:
# Variance: 85.01

# %% [markdown]
# STANDARD DEVIATION

# %%
# Compute standard deviation
std_dev_value = np.std(data_np)
print(f"Standard Deviation: {std_dev_value:.2f}")
# Out:
# Standard Deviation: 9.22

# %% [markdown]
# NORAMAL DISTRIBUTATION GRAPH

# %%
# Generate x values
x = np.linspace(min(data_np), max(data_np), 100)

# Calculate probability density
y = stats.norm.pdf(x, mean_value, std_dev_value)

# Plot graph
plt.plot(x, y)
plt.title("Normal Distribution")
plt.xlabel("Values")
plt.ylabel("Probability Density")
plt.show()

# %% [markdown]
# COIN TOSS SIMULATION

# %%
# Take number of tosses from user
n = int(input("Enter number of coin tosses: "))

# Simulate coin toss
tosses = np.random.choice(['Head', 'Tail'], size=n)

# Count results
heads = np.sum(tosses == 'Head')
tails = np.sum(tosses == 'Tail')

# Display results
print("Heads:", heads)
print("Tails:", tails)

# Calculate probability
print("Probability of Heads:", heads/n)
print("Probability of Tails:", tails/n)
# Out:
# Enter number of coin tosses: 100
# Heads: 46
# Tails: 54
# Probability of Heads: 0.46
# Probability of Tails: 0.54
