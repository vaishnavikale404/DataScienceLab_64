# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavikale404/DataScienceLab_64/blob/main/practical4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data set

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Create a user-defined dataset
data = list(map(float ,input("enter number separated by space:").split()))
print("User-defined Dataset:", data)



# Ensure data is a NumPy array for calculations
data_np = np.array(data)

# Compute mean using NumPy
mean_value = np.mean(data_np)

# Compute median using NumPy
median_value = np.median(data_np)

# Compute mode using SciPy (NumPy does not have a direct mode function)
mode_result = stats.mode(data_np)
mode_value = mode_result.mode # Handle scalar or array mode output

print(f"Mean: {mean_value:.2f}")
print(f"Median: {median_value:.2f}")
print(f"Mode: {mode_value}")
# Out:
# enter number separated by space:10 20 50 8 9 7 6 5
# User-defined Dataset: [10.0, 20.0, 50.0, 8.0, 9.0, 7.0, 6.0, 5.0]
# Mean: 14.38
# Median: 8.50
# Mode: 5.0
